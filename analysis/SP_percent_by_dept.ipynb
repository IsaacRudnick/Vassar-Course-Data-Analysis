# %% [markdown]
# # Percent of Courses That Require Special Permission by Department
#
# This notebook shows the percentage of courses that require special permission (SP) by department. \
# Data analyzed is from the most recent semester. \
# Each department is represented by a bar, and the percentage of SP courses is shown on the y-axis. \
# The department average is also shown as a horizontal line.

# %%
# %pip install -qqq matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from utils.attribute_percent_per_group import *

# %%
def has_sp_req(course) -> bool:
    return course['sp']

def course_dept(course) -> str:
    return course['dept']

attribute_per_group(has_sp_req, course_dept, 'SP Required by Department', 'Department')
