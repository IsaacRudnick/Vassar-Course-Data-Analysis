# %%
# %pip install -qqq matplotlib

# %%
import matplotlib.pyplot as plt
from utils.get_all_dfs import *

years = get_all_dfs("courses", by_year=True)

# %%
# Format of {year: count, ...} 
years_labs = {}

import pandas as pd
# read csv file
df = pd.read_csv("courses/200403.csv")
df.head()
# Out:
#       courseID                           title  units   sp  max  enr  avl  wl  \
# 0  AFRS-105-01  Religion/Civil Rights Movement    1.0  NaN   19   17    2   0
# 1  AFRS-108-01        Intro/African Literature    1.0  NaN   25    6   19   0
# 2  AFRS-200-01              Green Haven Prison    0.5   SP  999   20  979   0
# 3  AFRS-201-01   The Prison Experience/America    0.5   SP  999    3  996   0
# 4  AFRS-202-01                     Black Music    1.0  NaN   20   19    1   0
#
#     gm   yl  ... format     xlist     d1 time1  d2 time2          loc  \
# 0  NaN  NaN  ...    NaN  IS  AFRS  XRELI    MW NaN    MW  1200PM-0115
# 1  NaN  NaN  ...    NaN  IS  AFRS    NaN    MW NaN    MW  0130PM-0245
# 2   SU  NaN  ...    NaN  IS  AFRS    NaN     F NaN     F  1100AM-0400
# 3   SU  NaN  ...    NaN  IS  AFRS    NaN     F NaN     F  1100AM-0400
# 4   NR  NaN  ...    NaN  IS  AFRS  XMUSI    TR NaN    TR  1200PM-0115
#
#                                           instructor  courselength  dept
# 0  PM   NE 107     Weisenfeld, Judith            ...             1  AFRS
# 1  PM   NE 201     Gueye, Marame                 ...             1  AFRS
# 2  PM              Mamiya, Lawrence              ...             1  AFRS
# 3  PM              Mamiya, Lawrence              ...             1  AFRS
# 4  PM   SH 400     Reid, Dennis                  ...             1  AFRS
#
# [5 rows x 24 columns]
